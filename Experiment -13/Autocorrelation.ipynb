# %%
23#Write a program in python to generate an autocorrelation plot on the array of numbers

# %%
# Importing the libraries.
import matplotlib.pyplot as plt
import numpy as np

# Data for which we plot Autocorrelation.
data = np.array([12.0, 24.0, 7., 20.0,
                 7.0, 22.0, 18.0,22.0,
                6.0, 7.0, 20.0, 13.0,
                 8.0, 5.0, 8])

# Adding plot title.
plt.title("Autocorrelation Plot")

# Providing x-axis name.
plt.xlabel("Lags")

# Plotting the Autocorrelation plot.
plt.acorr(data, maxlags = 10)

# Displaying the plot.
print("The Autocorrelation plot for the data is:")
plt.grid(True)

plt.show()
# Out:
# The Autocorrelation plot for the data is:

# %%
######################################################################################3
It measures a set of current values against a set of past values and finds whether they correlate.
It is the correlation of one-time series data to another time series data which has a time lag.
It varies from +1 to -1.
An autocorrelation of +1 indicates that if time series one increases in value the time series 2 also increases in proportion to the change in time series 1.
An autocorrelation of -1 indicates that if time series one increases in value the time series 2 decreases in proportion to the change in time series 1.

# %%
24#Write a program in python to generate an autocorrelation plot on random numbers

# %%
# Importing the libraries.
import matplotlib.pyplot as plt
import numpy as np

# Data for which we plot Autocorrelation.
data = np.random.randn(1000)

# Adding plot title.
plt.title("Autocorrelation Plot")

# Providing x-axis name.
plt.xlabel("Lags")

# Plotting the Autocorrelation plot.
plt.acorr(data, maxlags = 10)

# Displaying the plot.
print("The Autocorrelation plot for the data is:")
plt.grid(True)

plt.show()
# Out:
# The Autocorrelation plot for the data is:

# %%
#need to resolve this erroe
# Importing the libraries.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Data for which we plot Autocorrelation.
data = pd.read_csv('WIPRO.csv')

# Adding plot title.
plt.title("Autocorrelation Plot")

# Providing x-axis name.
plt.xlabel("Lags")

# Plotting the Autocorrelation plot.
plt.acorr(data, maxlags = 10)

# Displaying the plot.
print("The Autocorrelation plot for the data is:")
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 16
#      13 plt.xlabel("Lags")
#      15 # Plotting the Autocorrelation plot.
# ---> 16 plt.acorr(data, maxlags = 10)
#      18 # Displaying the plot.
#      19 print("The Autocorrelation plot for the data is:")
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2361, in acorr(x, data, **kwargs)
#    2359 @_copy_docstring_and_deprecators(Axes.acorr)
#    2360 def acorr(x, *, data=None, **kwargs):
# -> 2361     return gca().acorr(
#    2362         x, **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1996, in Axes.acorr(self, x, **kwargs)
#    1926 @_preprocess_data(replace_names=["x"], label_namer="x")
#    1927 def acorr(self, x, **kwargs):
#    1928     """
#    1929     Plot the autocorrelation of *x*.
#    1930
#    (...)
#    1994     ``mode = "full"``.
#    1995     """
# -> 1996     return self.xcorr(x, x, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:2080, in Axes.xcorr(self, x, y, normed, detrend, usevlines, maxlags, **kwargs)
#    2077 x = detrend(np.asarray(x))
#    2078 y = detrend(np.asarray(y))
# -> 2080 correls = np.correlate(x, y, mode="full")
#    2082 if normed:
#    2083     correls /= np.sqrt(np.dot(x, x) * np.dot(y, y))
#
# File <__array_function__ internals>:180, in correlate(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\numeric.py:747, in correlate(a, v, mode)
#     676 @array_function_dispatch(_correlate_dispatcher)
#     677 def correlate(a, v, mode='valid'):
#     678     r"""
#     679     Cross-correlation of two 1-dimensional sequences.
#     680
#    (...)
#     745
#     746     """
# --> 747     return multiarray.correlate2(a, v, mode)
#
# ValueError: object too deep for desired array

# %%
# Importing the libraries.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Data for which we plot Autocorrelation.
data = pd.read_csv('Electric_Production.csv')

# Adding plot title.
plt.title("Autocorrelation Plot")

# Providing x-axis name.
plt.xlabel("Lags")

# Plotting the Autocorrelation plot.
plt.acorr(data, maxlags = 10)

# Displaying the plot.
print("The Autocorrelation plot for the data is:")
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 16
#      13 plt.xlabel("Lags")
#      15 # Plotting the Autocorrelation plot.
# ---> 16 plt.acorr(data, maxlags = 10)
#      18 # Displaying the plot.
#      19 print("The Autocorrelation plot for the data is:")
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2361, in acorr(x, data, **kwargs)
#    2359 @_copy_docstring_and_deprecators(Axes.acorr)
#    2360 def acorr(x, *, data=None, **kwargs):
# -> 2361     return gca().acorr(
#    2362         x, **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1996, in Axes.acorr(self, x, **kwargs)
#    1926 @_preprocess_data(replace_names=["x"], label_namer="x")
#    1927 def acorr(self, x, **kwargs):
#    1928     """
#    1929     Plot the autocorrelation of *x*.
#    1930
#    (...)
#    1994     ``mode = "full"``.
#    1995     """
# -> 1996     return self.xcorr(x, x, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:2080, in Axes.xcorr(self, x, y, normed, detrend, usevlines, maxlags, **kwargs)
#    2077 x = detrend(np.asarray(x))
#    2078 y = detrend(np.asarray(y))
# -> 2080 correls = np.correlate(x, y, mode="full")
#    2082 if normed:
#    2083     correls /= np.sqrt(np.dot(x, x) * np.dot(y, y))
#
# File <__array_function__ internals>:180, in correlate(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\numeric.py:747, in correlate(a, v, mode)
#     676 @array_function_dispatch(_correlate_dispatcher)
#     677 def correlate(a, v, mode='valid'):
#     678     r"""
#     679     Cross-correlation of two 1-dimensional sequences.
#     680
#    (...)
#     745
#     746     """
# --> 747     return multiarray.correlate2(a, v, mode)
#
# ValueError: object too deep for desired array

# %%
#XXXXXXXXXXXXXSHOW CSV FILE

# %%
import pandas as pd

# Reading the CSV file while dropping a column
df = pd.read_csv('Electric_Production.csv', usecols=lambda col: col not in ['DATE'])

# Displaying the resulting DataFrame
print(df)
# Out:
#      IPG2211A2N
# 0       72.5052
# 1       70.6720
# 2       62.4502
# 3       57.4714
# 4       55.3151
# ..          ...
# 392     98.6154
# 393     93.6137
# 394     97.3359
# 395    114.7212
# 396    129.4048
#
# [397 rows x 1 columns]

# %%
# Adding plot title.
plt.title("Autocorrelation Plot")

# Providing x-axis name.
plt.xlabel("Lags")

# Plotting the Autocorrelation plot.
plt.acorr(data, maxlags = 10)

# Displaying the plot.
print("The Autocorrelation plot for the data is:")
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 8
#       5 plt.xlabel("Lags")
#       7 # Plotting the Autocorrelation plot.
# ----> 8 plt.acorr(data, maxlags = 10)
#      10 # Displaying the plot.
#      11 print("The Autocorrelation plot for the data is:")
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2361, in acorr(x, data, **kwargs)
#    2359 @_copy_docstring_and_deprecators(Axes.acorr)
#    2360 def acorr(x, *, data=None, **kwargs):
# -> 2361     return gca().acorr(
#    2362         x, **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1996, in Axes.acorr(self, x, **kwargs)
#    1926 @_preprocess_data(replace_names=["x"], label_namer="x")
#    1927 def acorr(self, x, **kwargs):
#    1928     """
#    1929     Plot the autocorrelation of *x*.
#    1930
#    (...)
#    1994     ``mode = "full"``.
#    1995     """
# -> 1996     return self.xcorr(x, x, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:2080, in Axes.xcorr(self, x, y, normed, detrend, usevlines, maxlags, **kwargs)
#    2077 x = detrend(np.asarray(x))
#    2078 y = detrend(np.asarray(y))
# -> 2080 correls = np.correlate(x, y, mode="full")
#    2082 if normed:
#    2083     correls /= np.sqrt(np.dot(x, x) * np.dot(y, y))
#
# File <__array_function__ internals>:180, in correlate(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\numeric.py:747, in correlate(a, v, mode)
#     676 @array_function_dispatch(_correlate_dispatcher)
#     677 def correlate(a, v, mode='valid'):
#     678     r"""
#     679     Cross-correlation of two 1-dimensional sequences.
#     680
#    (...)
#     745
#     746     """
# --> 747     return multiarray.correlate2(a, v, mode)
#
# ValueError: object too deep for desired array

# %%
import pandas as pd

# Reading the CSV file while dropping a column
df = pd.read_csv('Shampoosale.csv', usecols=lambda col: col not in ['Month'])

# Displaying the resulting DataFrame
print(df)
# Out:
#     Sales of shampoo over a three year period
# 0                                       266.0
# 1                                       145.9
# 2                                       183.1
# 3                                       119.3
# 4                                       180.3
# 5                                       168.5
# 6                                       231.8
# 7                                       224.5
# 8                                       192.8
# 9                                       122.9
# 10                                      336.5
# 11                                      185.9
# 12                                      194.3
# 13                                      149.5
# 14                                      210.1
# 15                                      273.3
# 16                                      191.4
# 17                                      287.0
# 18                                      226.0
# 19                                      303.6
# 20                                      289.9
# 21                                      421.6
# 22                                      264.5
# 23                                      342.3
# 24                                      339.7
# 25                                      440.4
# 26                                      315.9
# 27                                      439.3
# 28                                      401.3
# 29                                      437.4
# 30                                      575.5
# 31                                      407.6
# 32                                      682.0
# 33                                      475.3
# 34                                      581.3
# 35                                      646.9

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Data for which we plot Autocorrelation.
data = pd.read_csv('Shampoosale.csv')

# Adding plot title.
plt.title("Autocorrelation Plot")

# Providing x-axis name.
plt.xlabel("Lags")

# Plotting the Autocorrelation plot.
plt.acorr(data, maxlags = 10)

# Displaying the plot.
print("The Autocorrelation plot for the data is:")
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 15
#      12 plt.xlabel("Lags")
#      14 # Plotting the Autocorrelation plot.
# ---> 15 plt.acorr(data, maxlags = 10)
#      17 # Displaying the plot.
#      18 print("The Autocorrelation plot for the data is:")
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2361, in acorr(x, data, **kwargs)
#    2359 @_copy_docstring_and_deprecators(Axes.acorr)
#    2360 def acorr(x, *, data=None, **kwargs):
# -> 2361     return gca().acorr(
#    2362         x, **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1996, in Axes.acorr(self, x, **kwargs)
#    1926 @_preprocess_data(replace_names=["x"], label_namer="x")
#    1927 def acorr(self, x, **kwargs):
#    1928     """
#    1929     Plot the autocorrelation of *x*.
#    1930
#    (...)
#    1994     ``mode = "full"``.
#    1995     """
# -> 1996     return self.xcorr(x, x, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:2080, in Axes.xcorr(self, x, y, normed, detrend, usevlines, maxlags, **kwargs)
#    2077 x = detrend(np.asarray(x))
#    2078 y = detrend(np.asarray(y))
# -> 2080 correls = np.correlate(x, y, mode="full")
#    2082 if normed:
#    2083     correls /= np.sqrt(np.dot(x, x) * np.dot(y, y))
#
# File <__array_function__ internals>:180, in correlate(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\numeric.py:747, in correlate(a, v, mode)
#     676 @array_function_dispatch(_correlate_dispatcher)
#     677 def correlate(a, v, mode='valid'):
#     678     r"""
#     679     Cross-correlation of two 1-dimensional sequences.
#     680
#    (...)
#     745
#     746     """
# --> 747     return multiarray.correlate2(a, v, mode)
#
# ValueError: object too deep for desired array
